# %% [markdown]
# <a href="https://colab.research.google.com/github/MAboElFottouh/data-structures-algorithms/blob/main/Reverse_Integer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given a signed 32-bit integer x, return x with its digits reversed. If reversing x causes the value to go outside the signed 32-bit integer range [-231, 231 - 1], then return 0.
#
# Assume the environment does not allow you to store 64-bit integers (signed or unsigned).

# %% [markdown]
# Input: x = 123
#
# Output: 321

# %% [markdown]
# Input: x = -123
#
# Output: -321

# %% [markdown]
# Input: x = 120
#
# Output: 21

# %%
def reverse(x):

  if x < 0 : # negative number convert to string and remove - from last and reverse and convert to int Again and add -  
      x = -int(str(x)[len(str(x))-1:0:-1])
  elif x > 0:# convert to string and reverse and convert to int again 
      x = int(str(x)[::-1])

  if (x > (-2**31) ) and (x < (2**31) ): # return only number in range 32bit 
    return x
  else :
    return 0

# %%
x = 120

# %%
reverse(x)
# Out:
# 21

# %%
x = -123

# %%
reverse(x)
# Out:
# -321

# %%
x = 123

# %%
reverse(x)
# Out:
# 321

# %%
x = 1534236469

# %%
reverse(x)
# Out:
# 0

# %%
1534236469 > (2**31)
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)
